# %% [markdown]
# # Aim:
#
# Perform Exploratory data analysis on Indian cuisine dataset and write the inferences for each question.
#
# i. Read the indianfood1.csv file into a DataFrame.
#
# ii. Explore size, shape, data types of each column in the dataset.
#
# iii. How many total Indian dishes are there?
#
# iv. How many different set of features are there in every Indian dish?
#
# v. Using Describe function, view the basic statistics of all columns. What Inference you can make out form that?
#
# vi. Are there any missing values in the dataset? If Yes, replace the missing values with the NaN values.
#
# vii. How many numeric features and categorical features are there in the dataset?
#
# viii. Display the number of unique values in each column.
#
# ix. Add a new column in the dataset to calculate the total time taken to make every dish.
#
# x. Add a new column in the dataset that will count the number of ingredients from the ingredients column for each dish

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#1
df=pd.read_csv("/content/seeds.csv")
df
# Out:
#       Area  Perimeter  Compactness  Kernel.Length  Kernel.Width  \
# 0    15.26      14.84       0.8710          5.763         3.312
# 1    14.88      14.57       0.8811          5.554         3.333
# 2    14.29      14.09       0.9050          5.291         3.337
# 3    13.84      13.94       0.8955          5.324         3.379
# 4    16.14      14.99       0.9034          5.658         3.562
# ..     ...        ...          ...            ...           ...
# 194  12.19      13.20       0.8783          5.137         2.981
# 195  11.23      12.88       0.8511          5.140         2.795
# 196  13.20      13.66       0.8883          5.236         3.232
# 197  11.84      13.21       0.8521          5.175         2.836
# 198  12.30      13.34       0.8684          5.243         2.974
#
#      Asymmetry.Coeff  Kernel.Groove  Type
# 0              2.221          5.220     1
# 1              1.018          4.956     1
# 2              2.699          4.825     1
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#2 
df.head()
# Out:
#     Area  Perimeter  Compactness  Kernel.Length  Kernel.Width  \
# 0  15.26      14.84       0.8710          5.763         3.312
# 1  14.88      14.57       0.8811          5.554         3.333
# 2  14.29      14.09       0.9050          5.291         3.337
# 3  13.84      13.94       0.8955          5.324         3.379
# 4  16.14      14.99       0.9034          5.658         3.562
#
#    Asymmetry.Coeff  Kernel.Groove  Type
# 0            2.221          5.220     1
# 1            1.018          4.956     1
# 2            2.699          4.825     1
# 3            2.259          4.805     1
# 4            1.355          5.175     1

# %%
df.describe()
# Out:
#              Area   Perimeter  Compactness  Kernel.Length  Kernel.Width  \
# count  199.000000  199.000000   199.000000     199.000000    199.000000
# mean    14.918744   14.595829     0.870811       5.643151      3.265533
# std      2.919976    1.310445     0.023320       0.443593      0.378322
# min     10.590000   12.410000     0.808100       4.899000      2.630000
# 25%     12.330000   13.470000     0.857100       5.267000      2.954500
# 50%     14.430000   14.370000     0.873400       5.541000      3.245000
# 75%     17.455000   15.805000     0.886800       6.002000      3.564500
# max     21.180000   17.250000     0.918300       6.675000      4.033000
#
#        Asymmetry.Coeff  Kernel.Groove        Type
# count       199.000000     199.000000  199.000000
# mean          3.699217       5.420653    1.994975
# std           1.471102       0.492718    0.813382
# min           0.765100       4.519000    1.000000
# 25%           2.570000       5.046000    1.000000
# ...

# %%
#3
sns.histplot(data=df, x="Type")
df['Type'].value_counts(ascending=True)
# Out:
# 3    65
# 1    66
# 2    68
# Name: Type, dtype: int64

# %%
#4
plt.scatter(x=df['Kernel.Width'], y=df['Kernel.Length'])

# %%
df.plot(kind='scatter',x='Kernel.Length',y='Kernel.Width')

# %% [markdown]
# INFERENCE: kernel length and kernel width are positively correlated with each other as the length increases width also increases. It is an approximate linear relationship

# %%
#5
sns.jointplot(x='Perimeter', y="Compactness",data=df,height=5)

# %%
plt.scatter(x=df['Perimeter'], y=df['Compactness'])

# %%
#6
sns.FacetGrid(df,hue="Type",height=5).map(plt.scatter,"Perimeter","Compactness").add_legend()

# %%
#7
sns.boxplot(x="Type",y="Compactness",data=df)

# %% [markdown]
# INFERENCE: Type 1 has outliers.
# EACH OF THE 3 TYPES COMPACTNESS IS DIFFERENT IQR IS DIFFERENT FOR EACH.

# %%
 #8
ax1=sns.boxplot(x="Type",y="Compactness",data=df)
ax2=sns.stripplot(x="Type",y="Compactness",data=df)

# %%
#9
ax1=sns.boxplot(x="Type",y="Perimeter",data=df)
ax2=sns.stripplot(x="Type",y="Perimeter",data=df)

# %%
#10
ax1=sns.violinplot(x="Type",y="Compactness",data=df)
ax1=sns.stripplot(x="Type",y="Compactness",data=df)

# %% [markdown]
# INFERENCE: Shape is determined by the distribution and range of features. Maximum no. of features are distributed in the broader region of the shape

# %%
#11
sns.FacetGrid(df,hue="Type",height=5).map(sns.kdeplot,"Compactness").add_legend()

# %% [markdown]
# INFERENCE: TYPE 3 IS MOST DISTRIBUTED AND TYPE 1 AND 2 ARE COMPACT AND OVERLAPPING. IT THAT MAKES IT DIFFICULT TO CLASSIFY

# %%
#12
sns.pairplot(df,hue="Type",height=3,diag_kind="hist")

# %%
#13
sns.pairplot(df,hue="Type",height=3)

# %%
#14
pd.plotting.andrews_curves(df,class_column="Type")

# %%
#15
X=[2,8,10]
Y=[11,16,9]
X2=[2,3,6]
Y2=[4,16,9]
plt.bar(X,Y)
# Out:
# <BarContainer object of 3 artists>

# %%
plt.bar(X2,Y2)
# Out:
# <BarContainer object of 3 artists>
